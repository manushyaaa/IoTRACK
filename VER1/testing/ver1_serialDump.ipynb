# %%
import datetime
import time

while True:
 
    current_time = datetime.datetime.now() 
    time_string = current_time.strftime("%H:%M:%S")
 
    print("\033c", end="") 
    print("Current time with seconds:", time_string)
     
    time.sleep(1)
# Out:
# cCurrent time with seconds: 00:35:35
# cCurrent time with seconds: 00:35:36
# cCurrent time with seconds: 00:35:37
# cCurrent time with seconds: 00:35:38
# cCurrent time with seconds: 00:35:39
# cCurrent time with seconds: 00:35:40
# cCurrent time with seconds: 00:35:41
# cCurrent time with seconds: 00:35:42
# cCurrent time with seconds: 00:35:43
# cCurrent time with seconds: 00:35:44
# cCurrent time with seconds: 00:35:45
# cCurrent time with seconds: 00:35:46
# cCurrent time with seconds: 00:35:47
# cCurrent time with seconds: 00:35:48
# cCurrent time with seconds: 00:35:49
# cCurrent time with seconds: 00:35:50
# cCurrent time with seconds: 00:35:51
# cCurrent time with seconds: 00:35:52
# cCurrent time with seconds: 00:35:53
# cCurrent time with seconds: 00:35:54
# cCurrent time with seconds: 00:35:55
# cCurrent time with seconds: 00:35:56
# cCurrent time with seconds: 00:35:57
# cCurrent time with seconds: 00:35:58
# cCurrent time with seconds: 00:35:59
# cCurrent time with seconds: 00:36:00
# cCurrent time with seconds: 00:36:01
# cCurrent time with seconds: 00:36:02
# cCurrent time with seconds: 00:36:03
# cCurrent time with seconds: 00:36:04
# cCurrent time with seconds: 00:36:05
# cCurrent time with seconds: 00:36:06
# cCurrent time with seconds: 00:36:07
# cCurrent time with seconds: 00:36:08
# cCurrent time with seconds: 00:36:09
# cCurrent time with seconds: 00:36:10
# cCurrent time with seconds: 00:36:11
# cCurrent time with seconds: 00:36:12
# cCurrent time with seconds: 00:36:13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      15 print("Current time with seconds:", time_string)
#      17 # Wait for 1 second before updating the time
# ---> 18 time.sleep(1)
#
# KeyboardInterrupt:

# %%
import pandas as pd
from datetime import datetime

# Read Excel file into DataFrame
df = pd.read_excel('G:\STS\data\predictedPath.xlsx')

# Convert time column to datetime
df['time'] = pd.to_datetime(df['time'])

# Get the current system time
current_time = datetime.now().strftime('%H:%M:%S')
current_time = '06:08:46'

# Filter the DataFrame based on the current system time
filtered_df = df[df['time'].dt.strftime('%H:%M:%S') == current_time]

# Print the filtered data
print(filtered_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 5
#       2 from datetime import datetime
#       4 # Read Excel file into DataFrame
# ----> 5 df = pd.read_excel('G:\STS\data\predictedPath.xlsx')
#       7 # Convert time column to datetime
#       8 df['time'] = pd.to_datetime(df['time'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\excel\_base.py:1500, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1496     ext = inspect_excel_format(
#    1497         content_or_path=path_or_buffer, storage_options=storage_options
#    1498     )
#    1499     if ext is None:
# -> 1500         raise ValueError(
#    1501             "Excel file format cannot be determined, you must specify "
#    1502             "an engine manually."
#    1503         )
#    1505 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1506 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
import datetime
import time
import pandas as pd


# Read Excel file into DataFrame
df = pd.read_excel('G:\STS\data\predictedPath.xlsx')

# Convert time column to datetime
 
df['time'] = pd.to_datetime(df['time'])
while True:
    
    current_time = datetime.datetime.now().strftime('%H:%M:%S') 
    filtered_df = df[df['time'].dt.strftime('%H:%M:%S') == current_time]

    # Print the filtered data
    print(filtered_df) 
    print(current_time)
    print("\033c", end="")  
     
    time.sleep(1)
# Out:
# C:\Users\manus\AppData\Local\Temp\ipykernel_28756\2980180469.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['time'] = pd.to_datetime(df['time'])
# Empty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:41
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:42
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:43
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:44
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:45
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:46
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:47
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:48
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:49
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:50
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:51
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:52
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:53
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:54
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:55
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:56
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:57
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:58
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:00:59
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:00
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:01
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:02
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:03
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:04
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:05
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:06
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:07
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:08
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:09
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:10
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:11
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:12
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:13
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:14
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:15
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:16
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:17
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:19
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:20
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:21
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:22
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:23
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:24
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:25
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:26
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:27
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:28
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:29
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:30
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:31
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:32
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:33
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:34
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:35
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:36
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:37
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:38
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:39
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:01:40
# c   Unnamed: 0  group event        date                time    azim  elev
# 1           1      1   NaN  06/18/2023 2023-06-18 06:03:38  239.83  0.08  \
#
#    distance  radialvelocity
# 1   2323.26        -6583.99
# 06:03:38
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:39
# c   Unnamed: 0  group event        date                time    azim  elev
# 2           2      1   NaN  06/18/2023 2023-06-18 06:03:40  239.95   0.2  \
#
#    distance  radialvelocity
# 2   2310.09        -6580.14
# 06:03:40
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:41
# c   Unnamed: 0  group event        date                time    azim  elev
# 3           3      1   NaN  06/18/2023 2023-06-18 06:03:42  240.06  0.32  \
#
#    distance  radialvelocity
# 3   2296.94        -6576.21
# 06:03:42
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:43
# c   Unnamed: 0  group event        date                time    azim  elev
# 4           4      1   NaN  06/18/2023 2023-06-18 06:03:44  240.17  0.44  \
#
#    distance  radialvelocity
# 4   2283.79        -6572.17
# 06:03:44
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:45
# c   Unnamed: 0  group event        date                time    azim  elev
# 5           5      1   NaN  06/18/2023 2023-06-18 06:03:46  240.29  0.56  \
#
#    distance  radialvelocity
# 5   2270.65        -6568.03
# 06:03:46
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:47
# c   Unnamed: 0  group event        date                time    azim  elev
# 6           6      1   NaN  06/18/2023 2023-06-18 06:03:48  240.41  0.68  \
#
#    distance  radialvelocity
# 6   2257.52        -6563.79
# 06:03:48
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:49
# c   Unnamed: 0  group event        date                time    azim  elev
# 7           7      1   NaN  06/18/2023 2023-06-18 06:03:50  240.53   0.8  \
#
#    distance  radialvelocity
# 7   2244.39        -6559.44
# 06:03:50
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:51
# c   Unnamed: 0  group event        date                time    azim  elev
# 8           8      1   NaN  06/18/2023 2023-06-18 06:03:52  240.65  0.93  \
#
#    distance  radialvelocity
# 8   2231.28        -6554.99
# 06:03:52
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:53
# c   Unnamed: 0  group event        date                time    azim  elev
# 9           9      1   NaN  06/18/2023 2023-06-18 06:03:54  240.77  1.05  \
#
#    distance  radialvelocity
# 9   2218.17        -6550.43
# 06:03:54
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:55
# c    Unnamed: 0  group event        date                time    azim  elev
# 10          10      1   NaN  06/18/2023 2023-06-18 06:03:56  240.89  1.17  \
#
#     distance  radialvelocity
# 10   2205.08        -6545.75
# 06:03:56
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:57
# c    Unnamed: 0  group event        date                time    azim  elev
# 11          11      1   NaN  06/18/2023 2023-06-18 06:03:58  241.02   1.3  \
#
#     distance  radialvelocity
# 11   2191.99        -6540.97
# 06:03:58
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:03:59
# c    Unnamed: 0  group event        date                time    azim  elev
# 12          12      1   NaN  06/18/2023 2023-06-18 06:04:00  241.14  1.43  \
#
#     distance  radialvelocity
# 12   2178.91        -6536.06
# 06:04:00
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:01
# c    Unnamed: 0  group event        date                time    azim  elev
# 13          13      1   NaN  06/18/2023 2023-06-18 06:04:02  241.27  1.55  \
#
#     distance  radialvelocity
# 13   2165.85        -6531.04
# 06:04:02
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:03
# c    Unnamed: 0  group event        date                time   azim  elev
# 14          14      1   NaN  06/18/2023 2023-06-18 06:04:04  241.4  1.68  \
#
#     distance  radialvelocity
# 14   2152.79        -6525.89
# 06:04:04
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:05
# c    Unnamed: 0  group event        date                time    azim  elev
# 15          15      1   NaN  06/18/2023 2023-06-18 06:04:06  241.53  1.81  \
#
#     distance  radialvelocity
# 15   2139.74        -6520.62
# 06:04:06
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:07
# c    Unnamed: 0  group event        date                time    azim  elev
# 16          16      1   NaN  06/18/2023 2023-06-18 06:04:08  241.66  1.94  \
#
#     distance  radialvelocity
# 16   2126.71        -6515.22
# 06:04:08
# c    Unnamed: 0  group event        date                time   azim  elev
# 17          17      1   NaN  06/18/2023 2023-06-18 06:04:10  241.8  2.07  \
#
#     distance  radialvelocity
# 17   2113.68         -6509.7
# 06:04:10
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:11
# c    Unnamed: 0  group event        date                time    azim  elev
# 18          18      1   NaN  06/18/2023 2023-06-18 06:04:12  241.93   2.2  \
#
#     distance  radialvelocity
# 18   2100.67        -6504.04
# 06:04:12
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:13
# c    Unnamed: 0  group event        date                time    azim  elev
# 19          19      1   NaN  06/18/2023 2023-06-18 06:04:14  242.07  2.33  \
#
#     distance  radialvelocity
# 19   2087.67        -6498.24
# 06:04:14
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:15
# c    Unnamed: 0  group event        date                time    azim  elev
# 20          20      1   NaN  06/18/2023 2023-06-18 06:04:16  242.21  2.46  \
#
#     distance  radialvelocity
# 20   2074.68         -6492.3
# 06:04:16
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:17
# c    Unnamed: 0  group event        date                time    azim  elev
# 21          21      1   NaN  06/18/2023 2023-06-18 06:04:18  242.35  2.59  \
#
#     distance  radialvelocity
# 21    2061.7        -6486.22
# 06:04:18
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:19
# c    Unnamed: 0  group event        date                time    azim  elev
# 22          22      1   NaN  06/18/2023 2023-06-18 06:04:20  242.49  2.73  \
#
#     distance  radialvelocity
# 22   2048.73         -6480.0
# 06:04:20
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:21
# c    Unnamed: 0  group event        date                time    azim  elev
# 23          23      1   NaN  06/18/2023 2023-06-18 06:04:22  242.64  2.86  \
#
#     distance  radialvelocity
# 23   2035.78        -6473.63
# 06:04:22
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:23
# c    Unnamed: 0  group event        date                time    azim  elev
# 24          24      1   NaN  06/18/2023 2023-06-18 06:04:24  242.78   3.0  \
#
#     distance  radialvelocity
# 24   2022.84         -6467.1
# 06:04:24
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:25
# c    Unnamed: 0  group event        date                time    azim  elev
# 25          25      1   NaN  06/18/2023 2023-06-18 06:04:26  242.93  3.13  \
#
#     distance  radialvelocity
# 25   2009.91        -6460.42
# 06:04:26
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:27
# c    Unnamed: 0  group event        date                time    azim  elev
# 26          26      1   NaN  06/18/2023 2023-06-18 06:04:28  243.08  3.27  \
#
#     distance  radialvelocity
# 26    1997.0        -6453.58
# 06:04:28
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:29
# c    Unnamed: 0  group event        date                time    azim  elev
# 27          27      1   NaN  06/18/2023 2023-06-18 06:04:30  243.23  3.41  \
#
#     distance  radialvelocity
# 27    1984.1        -6446.58
# 06:04:30
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:31
# c    Unnamed: 0  group event        date                time    azim  elev
# 28          28      1   NaN  06/18/2023 2023-06-18 06:04:32  243.39  3.55  \
#
#     distance  radialvelocity
# 28   1971.21        -6439.41
# 06:04:32
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:33
# c    Unnamed: 0  group event        date                time    azim  elev
# 29          29      1   NaN  06/18/2023 2023-06-18 06:04:34  243.54  3.68  \
#
#     distance  radialvelocity
# 29   1958.34        -6432.06
# 06:04:34
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:35
# c    Unnamed: 0  group event        date                time   azim  elev
# 30          30      1   NaN  06/18/2023 2023-06-18 06:04:36  243.7  3.83  \
#
#     distance  radialvelocity
# 30   1945.48        -6424.54
# 06:04:36
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:37
# c    Unnamed: 0  group event        date                time    azim  elev
# 31          31      1   NaN  06/18/2023 2023-06-18 06:04:38  243.86  3.97  \
#
#     distance  radialvelocity
# 31   1932.64        -6416.85
# 06:04:38
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:39
# c    Unnamed: 0  group event        date                time    azim  elev
# 32          32      1   NaN  06/18/2023 2023-06-18 06:04:40  244.02  4.11  \
#
#     distance  radialvelocity
# 32   1919.81        -6408.96
# 06:04:40
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:41
# c    Unnamed: 0  group event        date                time    azim  elev
# 33          33      1   NaN  06/18/2023 2023-06-18 06:04:42  244.19  4.25  \
#
#     distance  radialvelocity
# 33    1907.0        -6400.89
# 06:04:42
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:43
# c    Unnamed: 0  group event        date                time    azim  elev
# 34          34      1   NaN  06/18/2023 2023-06-18 06:04:44  244.36   4.4  \
#
#     distance  radialvelocity
# 34   1894.21        -6392.63
# 06:04:44
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:45
# c    Unnamed: 0  group event        date                time    azim  elev
# 35          35      1   NaN  06/18/2023 2023-06-18 06:04:46  244.53  4.54  \
#
#     distance  radialvelocity
# 35   1881.43        -6384.16
# 06:04:46
# cEmpty DataFrame
# Columns: [Unnamed: 0, group, event, date, time, azim, elev, distance, radialvelocity]
# Index: []
# 06:04:47
# c
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 22
#      19 print(current_time)
#      20 print("\033c", end="")
# ---> 22 time.sleep(1)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import time
import serial

ser = serial.Serial('COM1', 115200, timeout=0.050)
count = 0

while True:
    ser.write(f'Sent {count} time(s)'.encode())  # Encode the string as bytes before sending
    time.sleep(1)
    count += 1
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[3], line 4
#       1 import time
#       2 import serial
# ----> 4 ser = serial.Serial('COM1', 115200, timeout=0.050)
#       5 count = 0
#       7 while True:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      31 self._overlapped_read = None
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\serial\serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      62 if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#      67     self._overlapped_read = win32.OVERLAPPED()
#
# SerialException: could not open port 'COM1': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)

# %%
import serial.tools.list_ports

ports = serial.tools.list_ports.comports()
for port, desc, hwid in sorted(ports):
    print(f"Port: {port} | Description: {desc}")
